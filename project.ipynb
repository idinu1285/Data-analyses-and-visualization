# %% [markdown]
# ### Data analysis and visualization of a dataset
# ### Importing the modules needed to complete the project

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %% [markdown]
# ### Reading the dataset in the form of data frame and printing the first 15 rows and last 15 rows

# %%
filme = pd.read_csv('fisierul_meu.csv')
filme.head(15)
# Out:
#                               Titlu                      Tara  \
# 0                   Sons Of Dessert  United States of America
# 1                Gone With The Wind  United States of America
# 2   Crounching Tiger, Hidden Dragon                    Taiwan
# 3                  Internal Affairs                 Hong Kong
# 4                         Red Cliff                     China
# 5                        Wolf Creek                 Australia
# 6                     Andrei Rublev                    Russia
# 7                          Titanic   United States of America
# 8                         Duck Soup  United States of America
# 9                      Going My Way  United States of America
# 10                Dennis The Menace  United States of America
# 11                          RoboCop  United States of America
# 12                       Teddy Bear                    Poland
# 13                   The Terminator  United States of America
# ...

# %%
filme.tail(15)
# Out:
#                                 Titlu                      Tara  \
# 85                          Bad Taste               New Zeeland
# 86                     Spider - Man 2  United States of America
# 87             X -Men: The Last Stand  United States of America
# 88        The Cabinet of Dr. Caligari                   Germany
# 89                        El Mariachi                    Mexico
# 90                     The Good Earth  United States of America
# 91                      All About Eve  United States of America
# 92                   To Catch A Thief  United States of America
# 93                      Amores Perros                     Spain
# 94                    I Remember Mama  United States of America
# 95                         Casablanca  United States of America
# 96  The Lego Movie 2: The Second Part  United States of America
# 97                            Aladdin  United States of America
# 98                     A Star Is Born  United States of America
# ...

# %% [markdown]
# ###  Displaying the number of fields (lines x columns) of the dataframe

# %%
print(filme.shape)
# Out:
# (100, 12)

# %% [markdown]
# ### Displaying a summary of the dataframe that includes the data type and checking the lack of data

# %%
filme.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 12 columns):
# Titlu              100 non-null object
# Tara               100 non-null object
# Studio             100 non-null object
# Tip                100 non-null object
# An                 100 non-null int64
# Limba              100 non-null object
# Gen                100 non-null object
# Durata             100 non-null int64
# Regizor            100 non-null object
# Actor_principal    100 non-null object
# Rating             100 non-null float64
# Buget              100 non-null int64
# dtypes: float64(1), int64(3), object(8)
# memory usage: 9.5+ KB

# %% [markdown]
# ### Displaying the statistics of each column of the dataframe

# %%
filme.describe()
# Out:
#                An      Durata      Rating         Buget
# count   100.00000  100.000000  100.000000  1.000000e+02
# mean   1993.09000  123.000000    7.506000  4.545906e+07
# std      24.18201   36.327078    0.951535  7.398367e+07
# min    1915.00000   22.000000    5.300000  5.000000e+02
# 25%    1986.50000   97.750000    6.775000  1.000000e+06
# 50%    1999.00000  120.000000    7.500000  9.750000e+06
# 75%    2010.00000  138.000000    8.200000  5.125000e+07
# max    2019.00000  222.000000    9.800000  3.560000e+08

# %% [markdown]
# ### Preparing the dataframe before starting the data analysis
# ### Checking the duplicated and NaN values existing in the dataframe

# %%
print('Total of NaN values existing in dataframe are :\n',filme.isnull().sum())
print('Total of duplicated fields inserted in df are:',sum(filme.duplicated()))
# Out:
# Total of NaN values existing in dataframe are :
#  Titlu              0
# Tara               0
# Studio             0
# Tip                0
# An                 0
# Limba              0
# Gen                0
# Durata             0
# Regizor            0
# Actor_principal    0
# Rating             0
# Buget              0
# dtype: int64
# Total of duplicated fields inserted in df are: 0

# %% [markdown]
# ### Let's start doing a short data analysis of data frame

# %% [markdown]
# ### Displaying the titles of movies which starts with 'A' and  ends with 'n'

# %%
titlu_film = filme[(filme['Titlu'].str.startswith('A') & filme['Titlu'].str.endswith('n'))]['Titlu']
titlu_film
# Out:
# 35               Alladin
# 40    A Coffee in Berlin
# 41              Audition
# 97               Aladdin
# 98        A Star Is Born
# Name: Titlu, dtype: object

# %% [markdown]
# ### Sorting in descending order of the movie titles according to the year of production (the first 15 movie titles, respectively the last 15 movie titles)

# %%
sorting_movies_p15 = filme[['Titlu', 'An']].sort_values('An', ascending=False).head(15)
sorting_movies_u15 = filme[['Titlu', 'An']].sort_values('An', ascending=False).tail(15)

# %%
sorting_movies_p15
# Out:
#                                            Titlu    An
# 97                                       Aladdin  2019
# 96             The Lego Movie 2: The Second Part  2019
# 22                                       Shazam!  2019
# 72                                     Gully Boy  2019
# 21                              Avengers Endgame  2019
# 65                                  We Die Young  2019
# 64                Once Upon a Time..In Hollywood  2019
# 62                                      Homeward  2019
# 98                                A Star Is Born  2018
# 78                  Johnny English Strikes Again  2018
# 33  Pirates of Caribbean: Dead Men Tell No Tales  2017
# 99                                     Wild Oats  2016
# 60                         Battle for Sevastopol  2015
# 20                             Teminator Genesys  2015
# 14                                    Tangerines  2013

# %%
sorting_movies_u15
# Out:
#                              Titlu    An
# 25  Star Trek(TV Series 1966-1969)  1966
# 6                    Andrei Rublev  1966
# 46   The Good the Bad and the Ugly  1966
# 57          For a Few Dollars More  1965
# 92                To Catch A Thief  1955
# 91                   All About Eve  1950
# 94                 I Remember Mama  1948
# 9                     Going My Way  1944
# 95                      Casablanca  1942
# 1               Gone With The Wind  1939
# 90                  The Good Earth  1937
# 8                        Duck Soup  1933
# 0                  Sons Of Dessert  1933
# 88     The Cabinet of Dr. Caligari  1920
# 76           The Birth of A Nation  1915

# %% [markdown]
# ### Displaying movie titles that were produced in the United States and were produced in 20th Century Fox production studios

# %%
country_movie = filme[(filme['Tara'] == 'United States of America') & (filme['Studio'] == '20th Century Fox')][['Titlu','Studio','Tara']]
country_movie
# Out:
#                              Titlu            Studio                      Tara
# 7                         Titanic   20th Century Fox  United States of America
# 27  The Simpsons (TV Series 1988-)  20th Century Fox  United States of America
# 70                        Die Hard  20th Century Fox  United States of America
# 87          X -Men: The Last Stand  20th Century Fox  United States of America
# 91                   All About Eve  20th Century Fox  United States of America

# %% [markdown]
# ### Displaying movies with the lowest estimated budget, respectively the highest estimated budget

# %%
def low_high_budget(column):
    
    index_low = filme[column].idxmin()
    index_high = filme[column].idxmax()
    high = pd.DataFrame(filme.loc[index_high, :])
    low= pd.DataFrame(filme.loc[index_low, :])
    return pd.concat([high, low], axis=1)  

low_high_budget('Buget')
# Out:
#                                        21                        32
# Titlu                    Avengers Endgame          Owned & Operated
# Tara             United States of America  United States of America
# Studio                     Marvel Studios             Crackin Films
# Tip                                   Art                 Comercial
# An                                   2019                      2012
# Limba                             English                   English
# Gen                                Action               Documentary
# Durata                                181                       106
# Regizor                     Anthony Russo                     Relic
# Actor_principal         Robert Downey Jr.         Jiddu Kishnamurti
# Rating                                8.8                       8.1
# Buget                           356000000                       500

# %% [markdown]
# ### Displaying the titles, years of production and actors of movies like Thriller or Action genre

# %%
genre_movie = filme[(filme['Gen'] == 'Thriller') | (filme['Gen'] == 'Action')][['Titlu', 'Gen']]
genre_movie
# Out:
#                               Titlu       Gen
# 2   Crounching Tiger, Hidden Dragon    Action
# 4                         Red Cliff    Action
# 11                          RoboCop    Action
# 13                   The Terminator    Action
# 17      Terminator 2: Judgement Day    Action
# 20                Teminator Genesys    Action
# 21                 Avengers Endgame    Action
# 22                          Shazam!    Action
# 29                             Heat  Thriller
# 66                        King Kong    Action
# 68                       Apocalypto    Action
# 69                       The Colony    Action
# 70                         Die Hard  Thriller
# 73                        Rocky III    Action
# 74       Rambo: First Blood Part II    Action
# 75                           Rocky     Action
# 77                        Wateworld    Action
# 81                      John Carter    Action
# 86                   Spider - Man 2    Action
# ...

# %% [markdown]
# ### Displaying the names of the directors who directed films with a duration between 180 and 240 minutes

# %%
movie_duration = filme[(filme['Durata'] >= 180) & (filme['Durata'] <= 240)][[ 'Regizor','Durata']]
movie_duration
# Out:
#                  Regizor  Durata
# 1         Victor Fleming     222
# 6       Andrei Tarkovsky     205
# 7          James Cameron     194
# 18      Segiu Nicolaescu     203
# 21         Anthony Russo     181
# 30         Peter Jackson     201
# 45  Francis Ford Coppola     202
# 66         Peter Jackson     187
# 76        D. W. Griffith     195

# %% [markdown]
# ### Displaying  the average duration for each movie type

# %%
duration_mean = filme[['Durata', 'Gen']].groupby('Gen').mean()
duration_mean
# Out:
#                  Durata
# Gen
# Action       122.650000
# Adventure    108.000000
# Animation     79.750000
# Biography    131.500000
# Comedy       107.357143
# Crime        136.857143
# Documentary  104.000000
# Drama        127.894737
# Fantasy      134.400000
# History      203.000000
# Horror       104.000000
# Mistery      106.000000
# Musical       68.000000
# Romance      138.500000
# Sci-Fi        88.500000
# Thriller     151.000000
# War          150.333333
# Western      158.333333

# %% [markdown]
# ### Displaying the titles of the movies with the highest rating, respectively the lowest for each genre

# %%
rating_high_genre = filme.sort_values('Rating', ascending = False).groupby('Gen')['Titlu','Rating'].max()
rating_low_genre =  filme.sort_values('Rating', ascending = False).groupby('Gen')['Titlu','Rating'].min()

# %%
rating_high_genre
# Out:
#                                                     Titlu  Rating
# Gen
# Action                             X -Men: The Last Stand     8.8
# Adventure                                         Aladdin     7.4
# Animation                  The Simpsons (TV Series 1988-)     8.7
# Biography                                  Winnie Mandela     8.5
# Comedy                               White Cat, Black Cat     8.6
# Crime                             The Godfather - Part II     9.2
# Documentary                                       Samsara     8.5
# Drama                                        We Die Young     9.8
# Fantasy      The Lord Of The Ring: The Return of the King     8.9
# History                                    Mihai Viteazul     8.4
# Horror                                         Wolf Creek     7.5
# Mistery                                  To Catch A Thief     7.5
# Musical                                         Duck Soup     7.9
# ...

# %%
rating_low_genre
# Out:
#                                                     Titlu  Rating
# Gen
# Action                                         Apocalypto     5.3
# Adventure                                   Africa United     6.6
# Animation                                         Alladin     6.8
# Biography                                   Andrei Rublev     6.0
# Comedy                                 A Coffee in Berlin     5.6
# Crime                                               Belly     6.1
# Documentary                              Owned & Operated     8.1
# Drama                        4 Months, 3 Weeks and 2 Days     5.5
# Fantasy      Pirates of Caribbean: Dead Men Tell No Tales     6.6
# History                                    Mihai Viteazul     8.4
# Horror                                          Bad Taste     6.2
# Mistery                                  To Catch A Thief     7.5
# Musical                                         Duck Soup     7.9
# ...

# %% [markdown]
# ### Displaying the names of the actors who are the protagonists of the movies that have the main language Romanian or Spanish

# %%
# afisarea numelelor actorilor care sunt protagonistii filmelor care au limba principala lb. romana sau lb.spaniola
language_actor = filme[(filme['Limba'] == 'Romanian') | (filme['Limba'] == 'Spanish')]['Actor_principal']
language_actor
# Out:
# 15          Vlad Ivanov
# 18          Amza Pellea
# 80       Rober Pattison
# 89      Carlos Gallardo
# 93    Emilio Echevarria
# Name: Actor_principal, dtype: object

# %% [markdown]
# ### Finally let's make some data visualizations
# ### Graphical representation of the distributions of durations, ratings and production years

# %%
filme['Durata'].plot.hist(title='Distribution of movie durations', color = 'b')
plt.xlabel('Movie duration')
plt.ylabel('Movies total')
plt.show()
filme['Rating'].plot.hist(title='Distribution of movie ratings', color = 'b')
plt.xlabel('Movie rating')
plt.ylabel('Movies total')
plt.show()
filme['An'].plot.hist(title='Distribution of production years', color = 'b')
plt.xlabel('Production year')
plt.ylabel('Movies total')
plt.show()

# %% [markdown]
# ### Graphical representation of the correlation between the year of production and the duration of the movies

# %%
ax = sns.regplot(x=filme['An'], y=filme['Durata'],color='r')
ax.set_title('Correlation between production year and duration',fontsize=16)
ax.set_xlabel('Production year',fontsize=13)
ax.set_ylabel('Movie udaration[min]',fontsize=13)
sns.set(rc={'figure.figsize':(11,8)})
sns.set_style('ticks', {'xtick.major.size': 8, 'ytick.major.size': 8})
plt.show()

# %% [markdown]
# ### Graphical representation of the correlation between the production year and  budget of movies

# %%
ax = sns.regplot(x=filme['An'], y=filme['Buget'],color='r')
ax.set_title('Correlation between production year and estimated budget',fontsize=16)
ax.set_xlabel('Production year',fontsize=13)
ax.set_ylabel('Estimated budget [USD]',fontsize=13)
sns.set(rc={'figure.figsize':(11,8)})
sns.set_style('ticks', {'xtick.major.size': 8, 'ytick.major.size': 8})
plt.show()

# %% [markdown]
# ### Graphical representation of the correlation between the production year and rating of movies

# %%
ax = sns.regplot(x=filme['An'], y=filme['Rating'],color='r')
ax.set_title('Correlation between production year and rating',fontsize=16)
ax.set_xlabel('Production year',fontsize=13)
ax.set_ylabel('Movie rating',fontsize=13)
sns.set(rc={'figure.figsize':(11,8)})
sns.set_style('ticks', {'xtick.major.size': 8, 'ytick.major.size': 8})
plt.show()

# %% [markdown]
# ### Displaying a boxplot graph which represents the correlation between the type of movies and its duration

# %%
sns.boxplot(data=filme, x = 'Tip', y = 'Durata')
plt.title('Correlation between type and duration', fontsize = 16)
sns.set_style('ticks', {'xtick0.major.size': 8, 'ytick.major.size': 8})
plt.show()

# %% [markdown]
# ### Which is the top 20 best rated movies?

# %%
top_20_rating = filme.nlargest(20,'Rating')
sns.barplot(x='Rating', y='Titlu', data=top_20_rating, palette='Blues')
plt.xlabel('Movie rating')
plt.ylabel('Movie title')
sns.set(rc={'figure.figsize':(11,8)})
sns.set_style('ticks', {'xtick.major.size': 8, 'ytick.major.size': 8})
plt.title('Top 20 best rated movies', fontsize = 18)
plt.show()

# %% [markdown]
# ### Which is the top 20 longest movies?

# %%
top_20_durata = filme.nlargest(20,'Durata')
sns.barplot(x='Durata', y='Titlu', data=top_20_durata, palette='Greens')
plt.xlabel('Movie duration [min]')
plt.ylabel('Movie title')
sns.set(rc={'figure.figsize':(11,7)})
sns.set_style('ticks', {'xtick.major.size': 8, 'ytick.major.size': 8})
plt.title('Top 20 longest movies', fontsize = 18)
plt.show()

# %% [markdown]
# ### Displaying a lmplot graph which shows the relationship between rating, duration and main language of movie

# %%
sns.set_style('white')
sns.lmplot(data=filme, x='Rating', y='Durata', fit_reg=False, hue='Limba', size=6, aspect=1)
plt.title('Relation rating - duration - language', fontsize = 14)
plt.xlabel('Movie rating')
plt.ylabel('Movie duration [min]')
plt.show()

# %% [markdown]
# ### Displaying a lmplot grapg which shows the relationship between rating, duration and country  of movie

# %%
sns.set_style('white')
sns.lmplot(data=filme, x='Rating', y='Durata', fit_reg=False, hue='Tara', size=6, aspect=1)
plt.title('Relation rating - duration - country', fontsize = 14)
plt.xlabel('Movie rating')
plt.ylabel('Movie duration [min]')
sns.color_palette('dark')
plt.show()
